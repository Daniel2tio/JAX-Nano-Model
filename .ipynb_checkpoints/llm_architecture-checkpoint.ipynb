# %% [markdown]
# # Model Architecture

# %% [markdown]
# - We will use the tinystories dataset to create a 20M parameter model
# - We use TikToken to tokenise
# - THe use of a causal attention mask in order to prevent the model from seeing future tokens when predicting the next one

# %% [markdown]
# ## Importing Dependencies

# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
import tiktoken

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import jax
#       2 import jax.numpy as jnp
#       3 import flax.nnx as nnx
#       4 import tiktoken
#
# ModuleNotFoundError: No module named 'jax'
